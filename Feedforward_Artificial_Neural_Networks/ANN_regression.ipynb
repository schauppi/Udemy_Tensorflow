# %% [markdown]
# <a href="https://colab.research.google.com/github/schauppi/Udemy_Tensorflow/blob/schauppi/Feedforward_Artificial_Neural_Networks/ANN_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
N = 1000
X = np.random.random((N, 2)) * 6 - 3
Y = np.cos(2*X[:,0] + np.cos(3*X[:,1]))

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.scatter(X[:,0], X[:,1], Y)

# %%
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Dense(128, input_shape=(2,), activation="relu"),
                                    tf.keras.layers.Dense(1)
])

# %%
opt = tf.keras.optimizers.Adam(0.01)
model.compile(optimizer=opt, loss="mse")
history = model.fit(X, Y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 3s 2ms/step - loss: 0.5278
# Epoch 2/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4590
# Epoch 3/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4448
# Epoch 4/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4290
# Epoch 5/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4106
# Epoch 6/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3764
# Epoch 7/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3137
# Epoch 8/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2935
# Epoch 9/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2810
# Epoch 10/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2447
# Epoch 11/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2424
# Epoch 12/100
# ...

# %%
plt.plot(history.history["loss"], label="loss")
plt.legend()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.scatter(X[:,0], X[:,1], Y)
line = np.linspace(-3,3,50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.scatter(X[:,0], X[:,1], Y)
line = np.linspace(-5,5,50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()
